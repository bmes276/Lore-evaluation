# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

from lore_sa import sklearn_classifier_bbox

# %%
# Load dataset
df = pd.read_csv('german_credit.csv')

# Define X and y
X = df.drop(columns='default')
y = df['default']

# Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), [1, 4, 7, 10, 12, 15, 17]),
        ('cat', OrdinalEncoder(), [0, 2, 3, 5, 6, 8, 9, 11, 13, 14, 16, 18, 19])
    ]
)

# Build model pipeline
model = make_pipeline(preprocessor, RandomForestClassifier(n_estimators=100, random_state=42))

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Fit model
model.fit(X_train, y_train)

bbox = sklearn_classifier_bbox.sklearnBBox(model)

# %%
from lore_sa.dataset import TabularDataset
from lore_sa.neighgen import GeneticGenerator
from lore_sa.encoder_decoder import ColumnTransformerEnc
from lore_sa.lore import Lore
from lore_sa.surrogate import DecisionTreeSurrogate
from sklearn.preprocessing import FunctionTransformer  # For identity encoding

# Load dataset
dataset = TabularDataset.from_csv('german_credit.csv', class_name="default")
dataset.df.dropna(inplace=True)
dataset.update_descriptor()

enc = ColumnTransformerEnc(dataset.descriptor)
enc.target_encoder = FunctionTransformer(func=lambda x: x, inverse_func=lambda x: x)

generator = GeneticGenerator(bbox, dataset, enc)
surrogate = DecisionTreeSurrogate()

# Initialize Lore
tabularLore = Lore(bbox, dataset, enc, generator, surrogate)

# %%
instance_id = 7  # You can pick any row index
# Drop the target column 'default' before passing to explain
instance = dataset.df.drop(columns='default').iloc[instance_id]

# %%
explanation = tabularLore.explain(instance)
print(explanation)
# Out:
# {'rule': {'premises': [{'attr': 'purpose', 'val': '(vacation - does not exist?)', 'op': '!='}, {'attr': 'other_debtors', 'val': 'co-applicant', 'op': '!='}, {'attr': 'personal_status_sex', 'val': 'male : divorced/separated', 'op': '!='}, {'attr': 'property', 'val': 'unknown / no property', 'op': '!='}, {'attr': 'purpose', 'val': 'repairs', 'op': '!='}], 'consequence': {'attr': 'default', 'val': np.int64(0), 'op': '='}}, 'counterfactuals': [{'premises': [{'attr': 'purpose', 'val': '(vacation - does not exist?)', 'op': '!='}, {'attr': 'other_debtors', 'val': 'co-applicant', 'op': '!='}, {'attr': 'personal_status_sex', 'val': 'male : divorced/separated', 'op': '!='}, {'attr': 'property', 'val': 'unknown / no property', 'op': '='}, {'attr': 'credit_amount', 'val': np.float64(3974.0), 'op': '>'}, {'attr': 'telephone', 'val': 'none', 'op': '='}], 'consequence': {'attr': 'default', 'val': np.int64(1), 'op': '='}}], 'fidelity': 1.0, 'deltas': [[]], 'counterfactual_samples': [array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'), 'car (used)',
#        6948, np.str_('... < 100 DM'), np.str_('1 <= ... < 4 years'), 3,
#        np.str_('male : single'), np.str_('none'), 2,
#        np.str_('unknown / no property'), 35, np.str_('none'),
#        np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'), 'car (used)',
#        1000, np.str_('... < 100 DM'), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : single'), np.str_('none'), 3,
#        np.str_('unknown / no property'), 35, np.str_('none'),
#        np.str_('rent'), 1, np.str_('skilled employee / official'), 1,
#        np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'), 'car (used)',
#        13737, np.str_('... < 100 DM'), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : divorced/separated'), np.str_('none'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        'furniture/equipment', 6948, np.str_('... < 100 DM'),
#        np.str_('.. >= 7 years'), 2, np.str_('male : divorced/separated'),
#        np.str_('none'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('own'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 53,
#        np.str_('existing credits paid back duly till now'), 'car (used)',
#        6948, np.str_('... < 100 DM'), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : divorced/separated'), np.str_('none'), 2,
#        np.str_('unknown / no property'), 35, np.str_('none'),
#        np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'), 'car (used)',
#        6948, np.str_('... < 100 DM'), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : single'), np.str_('none'), 2,
#        np.str_('unknown / no property'), 22, np.str_('none'),
#        np.str_('own'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('no credits taken/ all credits paid back duly'),
#        '(vacation - does not exist?)', 6948, np.str_('.. >= 1000 DM '),
#        np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : married/widowed'), np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('own'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948,
#        np.str_('100 <= ... < 500 DM'), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : single'), np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('own'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('< 0 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2, np.str_('unknown / no property'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('< 0 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2, np.str_('unknown / no property'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('no')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 50,
#        np.str_('no credits taken/ all credits paid back duly'),
#        '(vacation - does not exist?)', 14220, np.str_('... < 100 DM'),
#        np.str_('... < 1 year '), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        35, np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('.. >= 1000 DM '),
#        np.str_('unemployed'), 2,
#        np.str_('female : divorced/separated/married'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 38,
#        np.str_('none'), np.str_('rent'), 2,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 2,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 69,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('unemployed/ unskilled - non-resident'), 1,
#        np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('unemployed/ unskilled - non-resident'), 1,
#        np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : married/widowed'), np.str_('co-applicant'), 1,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('skilled employee / official'), 1,
#        np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        'domestic appliances', 1450, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 14530,
#        np.str_('500 <= ... < 1000 DM '), np.str_('1 <= ... < 4 years'), 2,
#        np.str_('male : single'), np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('own'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 71,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 3,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 3,
#        np.str_('skilled employee / official'), 1,
#        np.str_('yes, registered under the customers name '),
#        np.str_('no')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
#        np.str_('none'), np.str_('rent'), 1,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1, np.str_('yes, registered under the customers name '),
#        np.str_('yes')], dtype=object), array([np.str_('0 <= ... < 200 DM'), 36,
#        np.str_('existing credits paid back duly till now'),
#        '(vacation - does not exist?)', 6948, np.str_('... < 100 DM'),
#        np.str_('1 <= ... < 4 years'), 2, np.str_('male : single'),
#        np.str_('co-applicant'), 2,
#        np.str_('if not A121/A122 : car or other, not in attribute 6'), 35,
# ...
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object), array([np.str_('>= 200 DM / salary assignments for at least 1 year'),
#        47.33261594876481, np.str_('delay in paying off in the past'),
#        '(vacation - does not exist?)', 18411.57526302914,
#        np.str_('.. >= 1000 DM '), np.str_('1 <= ... < 4 years'),
#        1.750269336097949, np.str_('male : divorced/separated'),
#        np.str_('none'), 1.303420498174559,
#        np.str_('if not A121 : building society savings agreement/ life insurance'),
#        66.59184400462215, np.str_('stores'), np.str_('own'),
#        2.3645994917033724,
#        np.str_('management/ self-employed/ highly qualified employee/ officer'),
#        1.971854076013654, np.str_('none'), np.str_('yes')], dtype=object)], 'counterfactual_predictions': [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int ...

# %%
def get_features_from_rule(explanation):
    return {premise['attr'] for premise in explanation['rule']['premises']}

# Example usage
features_used = get_features_from_rule(explanation)
print("Features used in the explanation (main rule):", features_used)
# Out:
# Features used in the explanation (main rule): {'property', 'other_debtors', 'purpose', 'personal_status_sex'}

# %%
prediction = model.predict([instance])
print(prediction)
# Out:
# [0]

# %%
# Step 2: Get predicted class
predicted_class = model.predict([instance])
print(predicted_class)

# Step 1: Get predicted probabilities
proba = model.predict_proba([instance])[0]  # Gives probabilities for each class
print(proba)
# Out:
# [0]
# [0.84 0.16]

# %%
# Step 3: Get index of predicted class
class_index = list(model.classes_).index(predicted_class)
print(class_index)

# Step 4: Get confidence score
original_confidence_score = proba[class_index]
print(original_confidence_score)
# Out:
# 0
# 0.84

# %%
import numpy as np

# Features to perturb
features_to_perturb = features_used

# Original instance
instance1 = dataset.df.iloc[instance_id].copy()
original_instance = instance1.drop(labels='default')

# Predict original class
original_pred_class = model.predict([original_instance])[0]
print(f"Original predicted class: {original_pred_class}")

def get_random_value_excluding(column, exclude_value):
    col_data = dataset.df[column].dropna()

    # Numerical feature
    if pd.api.types.is_numeric_dtype(col_data):
        # Calculate IQR
        Q1 = col_data.quantile(0.25)
        Q3 = col_data.quantile(0.75)
        IQR = Q3 - Q1

        # Define IQR range
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter values in IQR range (excluding the original value)
        filtered_values = col_data[(col_data >= lower_bound) & 
                                   (col_data <= upper_bound) & 
                                   (col_data != exclude_value)]

        if filtered_values.empty:
            return exclude_value  # fallback

        return np.random.choice(filtered_values)
    
    # Categorical feature
    else:
        unique_values = col_data.astype(str).unique()
        filtered_values = [val for val in unique_values if val != str(exclude_value)]
        
        if not filtered_values:
            return exclude_value  # fallback

        return np.random.choice(filtered_values)

# Lists for tracking
confidence_scores = []
class_changes = 0
n_iterations = 100

for i in range(n_iterations):
    # Perturb the instance
    perturbed_instance = original_instance.copy()
    for feature in features_to_perturb:
        perturbed_instance[feature] = get_random_value_excluding(feature, original_instance[feature])
    
    perturbed_df = pd.DataFrame([perturbed_instance])

    # Predict class and confidence
    predicted_proba = model.predict_proba(perturbed_df)[0]
    predicted_class = model.predict(perturbed_df)[0]
    confidence = predicted_proba[predicted_class]

    confidence_scores.append(confidence)

    # Check and report class change
    if predicted_class != original_pred_class:
        class_changes += 1
        print(f"[{i+1}] Class changed to: {predicted_class} with confidence: {confidence:.4f}")

# Summary
print(f"\nOut of {n_iterations} perturbations:")
print(f"- Class changed {class_changes} times")
print(f"- Mean confidence: {np.mean(confidence_scores):.4f}")
print(f"Min: {np.min(confidence_scores):.4f}, Max: {np.max(confidence_scores):.4f}")

# Difference from original
differences = [original_confidence_score - c for c in confidence_scores]
print(f"\nAverage drop in confidence vs. original: {np.mean(differences):.4f}")
# Out:
# Original predicted class: 0
# [1] Class changed to: 1 with confidence: 0.5100
# [2] Class changed to: 1 with confidence: 0.5800
# [3] Class changed to: 1 with confidence: 0.6600
# [7] Class changed to: 1 with confidence: 0.5600
# [8] Class changed to: 1 with confidence: 0.5800
# [9] Class changed to: 1 with confidence: 0.6700
# [10] Class changed to: 1 with confidence: 0.6400
# [13] Class changed to: 1 with confidence: 0.6200
# [14] Class changed to: 1 with confidence: 0.5700
# [15] Class changed to: 1 with confidence: 0.5100
# [16] Class changed to: 1 with confidence: 0.5700
# [17] Class changed to: 1 with confidence: 0.6900
# [18] Class changed to: 1 with confidence: 0.5900
# [19] Class changed to: 1 with confidence: 0.5400
# [20] Class changed to: 1 with confidence: 0.5800
# [23] Class changed to: 1 with confidence: 0.6200
# [24] Class changed to: 1 with confidence: 0.5500
# [25] Class changed to: 1 with confidence: 0.6200
# [26] Class changed to: 1 with confidence: 0.5800
# [27] Class changed to: 1 with confidence: 0.5700
# [28] Class changed to: 1 with confidence: 0.6600
# [30] Class changed to: 1 with confidence: 0.5700
# [31] Class changed to: 1 with confidence: 0.5400
# [32] Class changed to: 1 with confidence: 0.5400
# [33] Class changed to: 1 with confidence: 0.6900
# [39] Class changed to: 1 with confidence: 0.5800
# [40] Class changed to: 1 with confidence: 0.6000
# [41] Class changed to: 1 with confidence: 0.6000
# [42] Class changed to: 1 with confidence: 0.5700
# [44] Class changed to: 1 with confidence: 0.6000
# [45] Class changed to: 1 with confidence: 0.6900
# [47] Class changed to: 1 with confidence: 0.6600
# [48] Class changed to: 1 with confidence: 0.5300
# [50] Class changed to: 1 with confidence: 0.5600
# [51] Class changed to: 1 with confidence: 0.6000
# [52] Class changed to: 1 with confidence: 0.5200
# [53] Class changed to: 1 with confidence: 0.6800
# [54] Class changed to: 1 with confidence: 0.5900
# [56] Class changed to: 1 with confidence: 0.5800
# [57] Class changed to: 1 with confidence: 0.5200
# [58] Class changed to: 1 with confidence: 0.5800
# [59] Class changed to: 1 with confidence: 0.5200
# [60] Class changed to: 1 with confidence: 0.5400
# [62] Class changed to: 1 with confidence: 0.5200
# [63] Class changed to: 1 with confidence: 0.6900
# [66] Class changed to: 1 with confidence: 0.6000
# [68] Class changed to: 1 with confidence: 0.6300
# [71] Class changed to: 1 with confidence: 0.6900
# [74] Class changed to: 1 with confidence: 0.6100
# [75] Class changed to: 1 with confidence: 0.6400
# [76] Class changed to: 1 with confidence: 0.5100
# [77] Class changed to: 1 with confidence: 0.5300
# [78] Class changed to: 1 with confidence: 0.5300
# [79] Class changed to: 1 with confidence: 0.6700
# [80] Class changed to: 1 with confidence: 0.5900
# [81] Class changed to: 1 with confidence: 0.5800
# [82] Class changed to: 1 with confidence: 0.5900
# [84] Class changed to: 1 with confidence: 0.5700
# [86] Class changed to: 1 with confidence: 0.5100
# [88] Class changed to: 1 with confidence: 0.6000
# [89] Class changed to: 1 with confidence: 0.6000
# [90] Class changed to: 1 with confidence: 0.5400
# [91] Class changed to: 1 with confidence: 0.5300
# [92] Class changed to: 1 with confidence: 0.5800
# [93] Class changed to: 1 with confidence: 0.6000
# [94] Class changed to: 1 with confidence: 0.5700
# [95] Class changed to: 1 with confidence: 0.5200
# [96] Class changed to: 1 with confidence: 0.5800
# [99] Class changed to: 1 with confidence: 0.5900
#
# Out of 100 perturbations:
# - Class changed 69 times
# - Mean confidence: 0.5780
# Min: 0.5000, Max: 0.6900
#
# Average drop in confidence vs. original: 0.2620

# %%
def get_features_from_rule(explanation):
    return {premise['attr'] for premise in explanation['rule']['premises']}

# Get features used in the explanation
features_used = get_features_from_rule(explanation)

# Get all feature names from the dataset (excluding target column 'default')
all_features = dataset.df.drop(columns='default').columns

# Get features not used in the explanation
unused_features = [feature for feature in all_features if feature not in features_used]

print("Features NOT used in the explanation:", unused_features)
# Out:
# Features NOT used in the explanation: ['account_check_status', 'duration_in_month', 'credit_history', 'credit_amount', 'savings', 'present_emp_since', 'installment_as_income_perc', 'present_res_since', 'age', 'other_installment_plans', 'housing', 'credits_this_bank', 'job', 'people_under_maintenance', 'telephone', 'foreign_worker']

# %%
import numpy as np

# Features to perturb
features_to_perturb = unused_features

# Original instance
instance1 = dataset.df.iloc[instance_id].copy()
original_instance = instance1.drop(labels='default')

# Predict original class
original_pred_class = model.predict([original_instance])[0]
print(f"Original predicted class: {original_pred_class}")

def get_random_value_excluding(column, exclude_value):
    unique_values = dataset.df[column].dropna().unique()
    filtered_values = [val for val in unique_values if val != exclude_value]
    return np.random.choice(filtered_values)

# Lists for tracking
confidence_scores = []
class_changes = 0
n_iterations = 100

for i in range(n_iterations):
    # Perturb the instance
    perturbed_instance = original_instance.copy()
    for feature in features_to_perturb:
        perturbed_instance[feature] = get_random_value_excluding(feature, original_instance[feature])
    
    perturbed_df = pd.DataFrame([perturbed_instance])

    # Predict class and confidence
    predicted_proba = model.predict_proba(perturbed_df)[0]
    predicted_class = model.predict(perturbed_df)[0]
    confidence = predicted_proba[predicted_class]

    confidence_scores.append(confidence)

    # Check and report class change
    if predicted_class != original_pred_class:
        class_changes += 1
        print(f"[{i+1}] Class changed to: {predicted_class} with confidence: {confidence:.4f}")

# Summary
print(f"\nOut of {n_iterations} perturbations:")
print(f"- Class changed {class_changes} times")
print(f"- Mean confidence: {np.mean(confidence_scores):.4f}")
print(f"Min: {np.min(confidence_scores):.4f}, Max: {np.max(confidence_scores):.4f}")

# Difference from original
differences = [original_confidence_score - c for c in confidence_scores]
print(f"\nAverage drop in confidence vs. original: {np.mean(differences):.4f}")
# Out:
# Original predicted class: 0
# [7] Class changed to: 1 with confidence: 0.6000
# [17] Class changed to: 1 with confidence: 0.5100
# [31] Class changed to: 1 with confidence: 0.5100
# [35] Class changed to: 1 with confidence: 0.5100
# [41] Class changed to: 1 with confidence: 0.5100
#
# Out of 100 perturbations:
# - Class changed 5 times
# - Mean confidence: 0.6603
# Min: 0.5100, Max: 0.8600
#
# Average drop in confidence vs. original: 0.1797

# %%
import numpy as np

# Features to perturb
features_to_perturb = unused_features

# Original instance
instance1 = dataset.df.iloc[instance_id].copy()
original_instance = instance1.drop(labels='default')

# Predict original class
original_pred_class = model.predict([original_instance])[0]
print(f"Original predicted class: {original_pred_class}")

def get_random_value_excluding(column, exclude_value):
    col_data = dataset.df[column].dropna()

    # Numerical feature
    if pd.api.types.is_numeric_dtype(col_data):
        # Calculate IQR
        Q1 = col_data.quantile(0.25)
        Q3 = col_data.quantile(0.75)
        IQR = Q3 - Q1

        # Define IQR range
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter values in IQR range (excluding the original value)
        filtered_values = col_data[(col_data >= lower_bound) & 
                                   (col_data <= upper_bound) & 
                                   (col_data != exclude_value)]

        if filtered_values.empty:
            return exclude_value  # fallback

        return np.random.choice(filtered_values)
    
    # Categorical feature
    else:
        unique_values = col_data.astype(str).unique()
        filtered_values = [val for val in unique_values if val != str(exclude_value)]
        
        if not filtered_values:
            return exclude_value  # fallback

        return np.random.choice(filtered_values)

# Lists for tracking
confidence_scores = []
class_changes = 0
n_iterations = 100

for i in range(n_iterations):
    # Perturb the instance
    perturbed_instance = original_instance.copy()
    for feature in features_to_perturb:
        perturbed_instance[feature] = get_random_value_excluding(feature, original_instance[feature])
    
    perturbed_df = pd.DataFrame([perturbed_instance])

    # Predict class and confidence
    predicted_proba = model.predict_proba(perturbed_df)[0]
    predicted_class = model.predict(perturbed_df)[0]
    confidence = predicted_proba[predicted_class]

    confidence_scores.append(confidence)

    # Check and report class change
    if predicted_class != original_pred_class:
        class_changes += 1
        print(f"[{i+1}] Class changed to: {predicted_class} with confidence: {confidence:.4f}")

# Summary
print(f"\nOut of {n_iterations} perturbations:")
print(f"- Class changed {class_changes} times")
print(f"- Mean confidence: {np.mean(confidence_scores):.4f}")
print(f"Min: {np.min(confidence_scores):.4f}, Max: {np.max(confidence_scores):.4f}")

# Difference from original
differences = [original_confidence_score - c for c in confidence_scores]
print(f"\nAverage drop in confidence vs. original: {np.mean(differences):.4f}")
# Out:
# Original predicted class: 0
#
# Out of 100 perturbations:
# - Class changed 0 times
# - Mean confidence: 0.7127
# Min: 0.5300, Max: 0.9100
#
# Average drop in confidence vs. original: 0.1273
